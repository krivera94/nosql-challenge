# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
list_of_collections = db.list_collection_names()
list_of_collections
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
count

# Display the first document in the results using pprint
first_document = establishments.find_one(query)

pprint(first_document)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('650a42e1de60f6379484e2d8'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd

documents = list(establishments.find(query))

df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
df.shape[0]

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  650a42e1de60f6379484e2d8   110681                  0
# 1  650a42e1de60f6379484e659   612039                  0
# 2  650a42e2de60f6379484e963   730933                  0
# 3  650a42e2de60f6379484eb51   172735                  0
# 4  650a42e2de60f6379484eb60   172953                  0
# 5  650a42e2de60f6379484f4ff   512854                  0
# 6  650a42e2de60f6379484f720  1537089                  0
# 7  650a42e3de60f63794850c4b   155648                  0
# 8  650a42e3de60f6379485108f  1012883                  0
# 9  650a42e3de60f637948518a1   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "AddressLine2": "London",
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
count

# Display the first document in the results using pprint
first_document = establishments.find_one(query)
first_document
# Out:
# {'_id': ObjectId('650a42e4de60f6379485206f'),
#  'FHRSID': 294900,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000019066',
#  'BusinessName': 'Mv Valulla',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark',
#  'AddressLine2': 'London',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'PostCode': 'RM15 5QY',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2016-08-23T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('0.287555'),
#   'latitude': Decimal128('51.504071')},
#  'RightToReply': '',
#  'Distance': 4640.460834256174,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/294900'}]}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
len(df)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  650a42e4de60f6379485206f   294900                  0
# 1  650a42e4de60f63794853601  1408389                  0
# 2  650a42e5de60f63794853610  1438466                  0
# 3  650a42e5de60f63794853616  1156030                  0
# 4  650a42e5de60f6379485369c   776404                  0
# 5  650a42e5de60f6379485369d   930899                  0
# 6  650a42e5de60f637948536b8   875250                  0
# 7  650a42e5de60f637948536c8  1064870                  0
# 8  650a42e5de60f63794853772  1223157                  0
# 9  650a42e5de60f63794853773   996676                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0             PI/000019066                                         Mv Valulla
# 1              21/00294/CP                                           Foodyz21
# 2              22/00008/CP                     Finest Chicken Peri Peri Grill
# 3             PI/000297297                                               Bona
# 4              15/00376/CP        Toddleswood Pre-School At Willowbank School
# 5              16/00266/CP  The Contract Dining Company At Willow Bank Pri...
# 6              14/00066/CP                                      The Ness Cafe
# 7              18/00191/CP                                          Turo Turo
# 8              20/00040/CP                             Falconwood Food & Wine
# 9              17/00248/CP                                        Falcon News
#
#                 BusinessType  BusinessTypeID  \
# 0    Other catering premises            7841
# 1    Restaurant/Cafe/Canteen               1
# 2     Takeaway/sandwich shop            7844
# 3    Restaurant/Cafe/Canteen               1
# 4            Caring Premises               5
# 5  School/college/university            7845
# 6    Restaurant/Cafe/Canteen               1
# 7             Mobile caterer            7846
# 8          Retailers - other            4613
# 9          Retailers - other            4613
#
#                                         AddressLine1 AddressLine2  \
# 0  Reeds River Cruises LtdKings ReachRiver Thames...       London
# 1                                     513 Abbey Road       London
# 2                                     515 Abbey Road       London
# 3                                  25 Dartmouth Road       London
# 4                                      Seacourt Road       London
# 5                                      Seacourt Road       London
# 6                                     Belvedere Road       London
# 7                                  2 Portmeadow Walk       London
# 8                              15 Lingfield Crescent       London
# 9                               1 Lingfield Crescent       London
#
#   AddressLine3  ...                              LocalAuthorityWebSite  \
# 0               ...  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1               ...                           http://www.bexley.gov.uk
# 2               ...                           http://www.bexley.gov.uk
# 3               ...  http://www.lewisham.gov.uk/myservices/business...
# 4               ...                           http://www.bexley.gov.uk
# 5               ...                           http://www.bexley.gov.uk
# 6               ...                           http://www.bexley.gov.uk
# 7               ...                           http://www.bexley.gov.uk
# 8               ...                           http://www.bexley.gov.uk
# 9               ...                           http://www.bexley.gov.uk
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1             food.safety@bexley.gov.uk
# 2             food.safety@bexley.gov.uk
# 3         david.edwards@lewisham.gov.uk
# 4             food.safety@bexley.gov.uk
# 5             food.safety@bexley.gov.uk
# 6             food.safety@bexley.gov.uk
# 7             food.safety@bexley.gov.uk
# 8             food.safety@bexley.gov.uk
# 9             food.safety@bexley.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.287555, 'latitude': 51.504071}
# 1      {'longitude': 0.121862, 'latitude': 51.48992}
# 2    {'longitude': 0.121542, 'latitude': 51.4899259}
# 3   {'longitude': 0.0143445, 'latitude': 51.3831202}
# 4     {'longitude': 0.125247, 'latitude': 51.497376}
# 5     {'longitude': 0.125247, 'latitude': 51.497376}
# 6     {'longitude': 0.133478, 'latitude': 51.506094}
# 7  {'longitude': 0.125036999583244, 'latitude': 5...
# 8       {'longitude': 0.08122, 'latitude': 51.45912}
# 9  {'longitude': 0.0812200009822845, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4640.460834            False
# 1  4645.974290            False
# 2  4645.986171            False
# 3  4645.989753            False
# 4  4646.124520            False
# 5  4646.124520            False
# 6  4646.144584            False
# 7  4646.170654            False
# 8  4646.327301            False
# 9  4646.327364            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
pprint(penang_flavours)
# Out:
# {'AddressLine2': 'Greenwich',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'NewRatingPending': True,
#  'RatingValue': None,
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('650a43ecc282be62418b2081'),
#  'geocode': {'latitude': None, 'longitude': None}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.4820 
longitude = 0.0077

query = {
    "RatingValue": 5,
    "geocode.latitude": {"$gte": latitude - 0.01, "$lte": latitude + 0.01},
    "geocode.longitude": {"$gte": longitude - 0.01, "$lte": longitude + 0.01},
}
sort = [("scores.Hygiene", 1)]
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   650a42e5de60f6379485457a   694745                  0
# 1   650a42e5de60f63794854597   694716                  0
# 2   650a42e5de60f637948545b8   694759                  0
# 3   650a42e5de60f637948545c4   695398                  0
# 4   650a42e5de60f637948546a4  1009421                  0
# ..                       ...      ...                ...
# 81  650a42e5de60f63794854ae5  1174773                  0
# 82  650a42e5de60f63794854ae6  1111352                  0
# 83  650a42e5de60f63794854ae7  1392074                  0
# 84  650a42e5de60f63794854b33  1392073                  0
# 85  650a42e5de60f63794854b86  1361286                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000138254         Blackheath Preparatory School
# 1              PI/000132866            Blackheath Service Station
# 2              PI/000140584                    The Pointer School
# 3              PI/000184620                    The Pointer School
# 4              PI/000204113                      Boulangerie Jade
# ..                      ...                                   ...
# 81                    12950                    River Gardens Cafe
# 82                    12566                              The Coop
# 83                    14567  Kido Greenwich Nursery and Preschool
# 84                    14566            The Alphabet House Nursery
# 85                    14275                         Enderby house
#
#                              BusinessType  BusinessTypeID  \
# 0               School/college/university            7845
# 1                       Retailers - other            4613
# 2               School/college/university            7845
# 3               School/college/university            7845
# 4                 Restaurant/Cafe/Canteen               1
# ..                                    ...             ...
# 81                Restaurant/Cafe/Canteen               1
# 82  Retailers - supermarkets/hypermarkets            7840
# 83                        Caring Premises               5
# 84                        Caring Premises               5
# 85                      Pub/bar/nightclub            7843
#
#                                         AddressLine1 AddressLine2  \
# 0   Blackheath Preparatory School 4 St Germans Place
# 1      Petrol Filling Station 37A Shooters Hill Road
# 2              The Pointer School 19 Stratheden Road
# 3                              37 Shooters Hill Road
# 4                                   48 Vanbrugh Park
# ..                                               ...          ...
# 81                             20 River Gardens Walk
# 82                                 51 Banning Street
# 83                                 65 Banning Street
# 84                               11 Telegraph Avenue
# 85                 Enderby House 23 Telegraph Avenue
#
#    AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 1    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 2    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 3    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 4    Blackheath  ...  http://www.royalgreenwich.gov.uk
# ..          ...  ...                               ...
# 81    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 82    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 83    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 84    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 85    Greenwich  ...  http://www.royalgreenwich.gov.uk
#
#       LocalAuthorityEmailAddress  \
# 0   health@royalgreenwich.gov.uk
# 1   health@royalgreenwich.gov.uk
# 2   health@royalgreenwich.gov.uk
# 3   health@royalgreenwich.gov.uk
# 4   health@royalgreenwich.gov.uk
# ..                           ...
# 81  health@royalgreenwich.gov.uk
# 82  health@royalgreenwich.gov.uk
# 83  health@royalgreenwich.gov.uk
# 84  health@royalgreenwich.gov.uk
# 85  health@royalgreenwich.gov.uk
#
#                                                scores  SchemeType  \
# 0   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# ..                                                ...         ...
# 81  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 82  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 83  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 84  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 85  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.0157412, 'latitude': 51.47244}
# 1    {'longitude': 0.0169644, 'latitude': 51.4740557}
# 2     {'longitude': 0.0174893, 'latitude': 51.474856}
# 3    {'longitude': 0.0164424, 'latitude': 51.4739747}
# 4   {'longitude': 0.0166079998016357, 'latitude': ...
# ..                                                ...          ...
# 81   {'longitude': 0.0021042, 'latitude': 51.4875754}
# 82   {'longitude': 0.0021042, 'latitude': 51.4875754}
# 83   {'longitude': 0.0034929, 'latitude': 51.4889654}
# 84    {'longitude': 0.003459, 'latitude': 51.4904834}
# 85   {'longitude': 0.0027937, 'latitude': 51.4906894}
#
#        Distance NewRatingPending  \
# 0   4649.205171            False
# 1   4649.219631            False
# 2   4649.229752            False
# 3   4649.235724            False
# 4   4649.338461            False
# ..          ...              ...
# 81  4650.256681            False
# 82  4650.256681            False
# 83  4650.256844            False
# 84  4650.313613            False
# 85  4650.345429            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# ..                                                ...
# 81  {'dataSource': None, 'extractDate': '0001-01-0...
# 82  {'dataSource': None, 'extractDate': '0001-01-0...
# 83  {'dataSource': None, 'extractDate': '0001-01-0...
# 84  {'dataSource': None, 'extractDate': '0001-01-0...
# 85  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# ..                                                ...
# 81  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 82  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 83  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 84  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 85  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [86 rows x 28 columns]

# %%
# Convert result to Pandas DataFrame
results = establishments.find(query)
df = pd.DataFrame(results)

df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   650a42e5de60f6379485457a   694745                  0
# 1   650a42e5de60f63794854597   694716                  0
# 2   650a42e5de60f637948545b8   694759                  0
# 3   650a42e5de60f637948545c4   695398                  0
# 4   650a42e5de60f637948546a4  1009421                  0
# ..                       ...      ...                ...
# 81  650a42e5de60f63794854ae5  1174773                  0
# 82  650a42e5de60f63794854ae6  1111352                  0
# 83  650a42e5de60f63794854ae7  1392074                  0
# 84  650a42e5de60f63794854b33  1392073                  0
# 85  650a42e5de60f63794854b86  1361286                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000138254         Blackheath Preparatory School
# 1              PI/000132866            Blackheath Service Station
# 2              PI/000140584                    The Pointer School
# 3              PI/000184620                    The Pointer School
# 4              PI/000204113                      Boulangerie Jade
# ..                      ...                                   ...
# 81                    12950                    River Gardens Cafe
# 82                    12566                              The Coop
# 83                    14567  Kido Greenwich Nursery and Preschool
# 84                    14566            The Alphabet House Nursery
# 85                    14275                         Enderby house
#
#                              BusinessType  BusinessTypeID  \
# 0               School/college/university            7845
# 1                       Retailers - other            4613
# 2               School/college/university            7845
# 3               School/college/university            7845
# 4                 Restaurant/Cafe/Canteen               1
# ..                                    ...             ...
# 81                Restaurant/Cafe/Canteen               1
# 82  Retailers - supermarkets/hypermarkets            7840
# 83                        Caring Premises               5
# 84                        Caring Premises               5
# 85                      Pub/bar/nightclub            7843
#
#                                         AddressLine1 AddressLine2  \
# 0   Blackheath Preparatory School 4 St Germans Place
# 1      Petrol Filling Station 37A Shooters Hill Road
# 2              The Pointer School 19 Stratheden Road
# 3                              37 Shooters Hill Road
# 4                                   48 Vanbrugh Park
# ..                                               ...          ...
# 81                             20 River Gardens Walk
# 82                                 51 Banning Street
# 83                                 65 Banning Street
# 84                               11 Telegraph Avenue
# 85                 Enderby House 23 Telegraph Avenue
#
#    AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 1    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 2    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 3    Blackheath  ...  http://www.royalgreenwich.gov.uk
# 4    Blackheath  ...  http://www.royalgreenwich.gov.uk
# ..          ...  ...                               ...
# 81    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 82    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 83    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 84    Greenwich  ...  http://www.royalgreenwich.gov.uk
# 85    Greenwich  ...  http://www.royalgreenwich.gov.uk
#
#       LocalAuthorityEmailAddress  \
# 0   health@royalgreenwich.gov.uk
# 1   health@royalgreenwich.gov.uk
# 2   health@royalgreenwich.gov.uk
# 3   health@royalgreenwich.gov.uk
# 4   health@royalgreenwich.gov.uk
# ..                           ...
# 81  health@royalgreenwich.gov.uk
# 82  health@royalgreenwich.gov.uk
# 83  health@royalgreenwich.gov.uk
# 84  health@royalgreenwich.gov.uk
# 85  health@royalgreenwich.gov.uk
#
#                                                scores  SchemeType  \
# 0   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# ..                                                ...         ...
# 81  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 82  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 83  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 84  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 85  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.0157412, 'latitude': 51.47244}
# 1    {'longitude': 0.0169644, 'latitude': 51.4740557}
# 2     {'longitude': 0.0174893, 'latitude': 51.474856}
# 3    {'longitude': 0.0164424, 'latitude': 51.4739747}
# 4   {'longitude': 0.0166079998016357, 'latitude': ...
# ..                                                ...          ...
# 81   {'longitude': 0.0021042, 'latitude': 51.4875754}
# 82   {'longitude': 0.0021042, 'latitude': 51.4875754}
# 83   {'longitude': 0.0034929, 'latitude': 51.4889654}
# 84    {'longitude': 0.003459, 'latitude': 51.4904834}
# 85   {'longitude': 0.0027937, 'latitude': 51.4906894}
#
#        Distance NewRatingPending  \
# 0   4649.205171            False
# 1   4649.219631            False
# 2   4649.229752            False
# 3   4649.235724            False
# 4   4649.338461            False
# ..          ...              ...
# 81  4650.256681            False
# 82  4650.256681            False
# 83  4650.256844            False
# 84  4650.313613            False
# 85  4650.345429            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# ..                                                ...
# 81  {'dataSource': None, 'extractDate': '0001-01-0...
# 82  {'dataSource': None, 'extractDate': '0001-01-0...
# 83  {'dataSource': None, 'extractDate': '0001-01-0...
# 84  {'dataSource': None, 'extractDate': '0001-01-0...
# 85  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# ..                                                ...
# 81  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 82  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 83  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 84  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 85  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [86 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {
        "$match": {"scores.Hygiene": 0}
    },
    {
        "$group": {
            "_id": "$LocalAuthorityName",
            "count": {"$sum": 1}
        }
    },
    {
        "$sort": {"count": -1}
    }
]

result = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
len(result)
# Print the first 10 results
for i, doc in enumerate(result[:10]):
    print(f"{i+1}. Local Authority: {doc['_id']}, Count: {doc['count']}")
# Out:
# 1. Local Authority: Thanet, Count: 1130
# 2. Local Authority: Greenwich, Count: 882
# 3. Local Authority: Maidstone, Count: 713
# 4. Local Authority: Newham, Count: 711
# 5. Local Authority: Swale, Count: 686
# 6. Local Authority: Chelmsford, Count: 680
# 7. Local Authority: Medway, Count: 672
# 8. Local Authority: Bexley, Count: 607
# 9. Local Authority: Southend-On-Sea, Count: 586
# 10. Local Authority: Tendring, Count: 542

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
num_rows = len(df)
print(num_rows)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
